# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import urllib
import datetime as dt

# %%
# %matplotlib inline

#%matplotlib notebook

# %%
def download_file(file_url, output_file):
    urllib.request.urlretrieve(file_url, output_file)
    return '{0} downloaded succesfully'.format(output_file)

# %%
ftp_url = 'ftp://ftp.ncdc.noaa.gov/pub/data/ghcn/daily/'

# %%
file_name = 'readme.txt'
download_url = urllib.parse.urljoin(ftp_url, file_name)

# %%
with open('readme.txt','r') as readme_file:
    for line in readme_file.readlines()[392:405]:
        print(line.rstrip())
# Out:
# ------------------------------
# Variable   Columns   Type
# ------------------------------
# ID            1-11   Character
# LATITUDE     13-20   Real
# LONGITUDE    22-30   Real
# ELEVATION    32-37   Real
# STATE        39-40   Character
# NAME         42-71   Character
# GSN FLAG     73-75   Character
# HCN/CRN FLAG 77-79   Character
# WMO ID       81-85   Character
# ------------------------------

# %%
file_name = 'ghcnd-stations.txt'
output_name = 'stations.txt'
download_url = urllib.parse.urljoin(ftp_url, file_name)

#download_file(download_url, output_name)

# %%
with open('stations.txt','r') as readme_file:
    for line in readme_file.readlines()[:10]:
        print(line.rstrip())
# Out:
# ACW00011604  17.1167  -61.7833   10.1    ST JOHNS COOLIDGE FLD
# ACW00011647  17.1333  -61.7833   19.2    ST JOHNS
# AE000041196  25.3330   55.5170   34.0    SHARJAH INTER. AIRP            GSN     41196
# AEM00041194  25.2550   55.3640   10.4    DUBAI INTL                             41194
# AEM00041217  24.4330   54.6510   26.8    ABU DHABI INTL                         41217
# AEM00041218  24.2620   55.6090  264.9    AL AIN INTL                            41218
# AF000040930  35.3170   69.0170 3366.0    NORTH-SALANG                   GSN     40930
# AFM00040938  34.2100   62.2280  977.2    HERAT                                  40938
# AFM00040948  34.5660   69.2120 1791.3    KABUL INTL                             40948
# AFM00040990  31.5000   65.8500 1010.0    KANDAHAR AIRPORT                       40990

# %% [markdown]
# ### Parse the selected columns from stations.txt

# %%
def parse_fixed_file(file_name, 
                     file_delimiter,
                     selected_columns,
                     column_types):
    return np.genfromtxt(file_name,
                         delimiter = file_delimiter,
                         usecols = selected_columns,
                         dtype = column_types)

# %%
file_delimiter = (11, 9, 10, 7, 3, 31, 4, 4, 6) 
selected_columns = [0, 5, 6] 

column_types = np.dtype([('ID', 'U11'),
                         ('NAME', 'S31'),
                         ('GSN_FLAG', 'U4')])

stations_raw = parse_fixed_file(file_name='stations.txt',
                                file_delimiter=file_delimiter,
                                selected_columns=selected_columns,
                                column_types=column_types)

# %%
stations_raw
# Out:
# array([('ACW00011604', b' ST JOHNS COOLIDGE FLD         ', '    '),
#        ('ACW00011647', b' ST JOHNS                      ', '    '),
#        ('AE000041196', b' SHARJAH INTER. AIRP           ', ' GSN'), ...,
#        ('ZI000067977', b' BUFFALO RANGE                 ', '    '),
#        ('ZI000067983', b' CHIPINGE                      ', ' GSN'),
#        ('ZI000067991', b' BEITBRIDGE                    ', '    ')],
#       dtype=[('ID', '<U11'), ('NAME', 'S31'), ('GSN_FLAG', '<U4')])

# %%
stations_raw.shape
# Out:
# (104126,)

# %%
gsn_stations = np.array([station for station in stations_raw if 'GSN' in station[2]])
print("Number of GSN stations:",len(gsn_stations))
# Out:
# Number of GSN stations: 991

# %%
gsn_stations['NAME'] = np.array([station_name.strip() for station_name in list(gsn_stations['NAME'])])
gsn_stations[:10]
# Out:
# array([('AE000041196', b'SHARJAH INTER. AIRP', ' GSN'),
#        ('AF000040930', b'NORTH-SALANG', ' GSN'),
#        ('AG000060390', b'ALGER-DAR EL BEIDA', ' GSN'),
#        ('AG000060590', b'EL-GOLEA', ' GSN'),
#        ('AG000060611', b'IN-AMENAS', ' GSN'),
#        ('AG000060680', b'TAMANRASSET', ' GSN'),
#        ('AJ000037989', b'ASTARA', ' GSN'),
#        ('ALM00013615', b'TIRANA RINAS', ' GSN'),
#        ('AM000037781', b'ARAGAC VISOKOGORNAYA', ' GSN'),
#        ('AO000066160', b'LUANDA', ' GSN')],
#       dtype=[('ID', '<U11'), ('NAME', 'S31'), ('GSN_FLAG', '<U4')])

# %%
station_mapping = {station[1]: station[0] for station in gsn_stations}
station_mapping
# Out:
# {b'ABILENE RGNL AP': 'USW00013962',
#  b'ABU HAMED': 'SU000062640',
#  b'ACAJUTLA': 'ES000078650',
#  b'ADDIS ABABA-BOLE': 'ET000063450',
#  b'ADIAKE': 'IV000065585',
#  b'AEROP.INTERNACIONAL': 'MX000076644',
#  b'AGADEZ': 'NG000061024',
#  b'AGALEGA': 'MP000061974',
#  b'AGATA': 'RSM00023383',
#  b'AJAN': 'RSM00031168',
#  b'AKITA': 'JA000047582',
#  b'AKUREYRI': 'IC000004063',
#  b'AL-JOUF': 'SA000040361',
#  b'AL-MADINAH': 'SA000040430',
#  b'ALBACETE LOS LLANOS': 'SP000008280',
#  b'ALBANY AIRPORT': 'ASN00009741',
#  b'ALBUQUERQUE INTL AP': 'USW00023050',
#  b'ALDAN': 'RSM00031004',
#  b'ALEKSANDROVSK-SAHALINSKIJ': 'RSM00032061',
#  b'ALEKSANDROVSKOE': 'RSM00023955',
#  b'ALERT CLIMATE': 'CA002400305',
#  b'ALFRED FAURE (ILES CROZET)': 'FSM00061997',
#  b'ALGER-DAR EL BEIDA': 'AG000060390',
#  b'ALICE SPRINGS AIRPORT': 'ASN00015590',
#  b'ALMATY': 'KZ000036870',
#  b'ALTAY': 'CHM00051076',
#  b'AM-TIMAN': 'CD000064754',
#  b'AMBON/PATTIMURA': 'ID000097724',
#  b'AMUNDSEN-SCOTT': 'AYW00090001',
#  b'ANADYR': 'RSM00025563',
#  b'ANALALAVA': 'MA000067019',
#  b'ANEITYUM': 'NH000091568',
#  b'ANNETTE ISLAND AP': 'USW00025308',
#  b'ANTANANARIVO/IVATO': 'MA000067083',
#  b'ANTOFAGASTA': 'CI000085442',
#  b'ANTSIRABATO': 'MAM00067025',
#  b'ANTSIRANANA': 'MA000067009',
#  b'APARRI': 'RP000098232',
#  b'ARAGAC VISOKOGORNAYA': 'AM000037781',
#  b'ARANYAPRATHET': 'TH000048462',
#  b'ARCTIC BAY CS': 'CA002400404',
#  b'AREQUIPA': 'PE000084752',
#  b'ARHANGELSK': 'RSM00022550',
#  b'ARICA': 'CI000085406',
#  b'ARVAIHEER': 'MG000044288',
#  b'ARVIAT CLIMATE': 'CA002301153',
#  b'ASKANIIA NOVA': 'UPM00033915',
#  b'ASMARA': 'ER000063021',
#  b'ASSWAN': 'EG000062414',
#  b'ASTARA': 'AJ000037989',
#  b'ASTRAKAN': 'RSM00034880',
#  b'ATAR': 'MR000061421',
#  b'ATBASAR': 'KZ000035078',
#  b'ATI': 'CD000064751',
#  b'BAGDARIN': 'RSM00030554',
#  b'BAGOTVILLE A': 'CA007060400',
#  b'BAHARIA': 'EG000624200',
#  b'BAHIA BLANCA AERO': 'AR000877500',
#  b'BAHRAIN (INT. AIRPO': 'BA000041150',
#  b'BAJKIT': 'RSM00023891',
#  b'BAJRAMALY': 'TX000038895',
#  b'BAKER LAKE CLIMATE': 'CA002300501',
#  b'BALHASH': 'KZ000035796',
#  b'BALMACEDA': 'CI000085874',
#  b'BANFF CS': 'CA003050519',
#  b'BANGALORE': 'IN009010100',
#  b'BARABINSK': 'RSM00029612',
#  b'BARCELONA/AEROPUERTO': 'SP000008181',
#  b'BARCELOS': 'BRM00082113',
#  b'BARGUZIN': 'RSM00030636',
#  b'BARRA DO CORDA': 'BR036190520',
#  b'BARREIRAS': 'BR047403040',
#  b'BARROW POST ROGERS AP': 'USW00027502',
#  b'BARTER ISLAND WSO AP': 'USW00027401',
#  b'BASE BAIA TERRA NOVA': 'AYM00089662',
#  b'BASE ESPERANZA': 'AYM00088963',
#  b'BASE MARAMBIO': 'AYM00089055',
#  b'BASE ORCADAS': 'AYM00088968',
#  b'BEGUMPET        OBSY': 'IN001080500',
#  b'BEIJING': 'CHM00054511',
#  b'BEIRA': 'MZ000067297',
#  b'BELLINGSHAUSEN AWS': 'AYM00089050',
#  b'BELY ISLAND': 'RSM00020667',
#  b'BENGHAZI BENINA': 'LYE00147747',
#  b'BENJAMIN CONSTANT': 'BRM00082410',
#  b'BERENS RIVER CS': 'CA005030203',
#  b'BEREZOVO': 'RSM00023631',
#  b'BETHEL AP': 'USW00026615',
#  b'BETHLEHEM': 'SFM00068461',
#  b'BEZENCHUK': 'RSM00027995',
#  b'BIAK/FRANS KAISIEPO': 'ID000097560',
#  b'BIG TROUT LAKE READAC': 'CA006010739',
#  b'BIJSK ZONALNAJA': 'RSM00029939',
#  b'BIKANER': 'IN019070100',
#  b'BILMA': 'NG000061017',
#  b'BINTULU': 'MY000096441',
#  b'BIR MOGHREIN': 'MR000061401',
#  b'BIRDSVILLE AIRPORT': 'ASN00038026',
#  b'BISER': 'RSM00028138',
#  b'BISHKEK': 'KG000038353',
#  b'BISMARCK': 'USW00024011',
#  b'BISTRITA': 'ROM00015085',
#  b'BJELASNICA': 'BKM00014652',
#  b'BJOERNOEYA': 'NO000099710',
#  b'BLAGNAC AEROP. TOULOUSE-BLAGNA': 'FR000007630',
#  b'BLOEMFONTEIN AIRPOR': 'SF002613650',
#  b'BLUE HILL': 'USW00014753',
#  b'BOA VISTA': 'BRM00082024',
#  b'BODO VI': 'NO000011520',
#  b'BOGOTA/ELDORADO': 'CO000080222',
#  b'BOGUCANY': 'RSM00029282',
#  b'BOISE AIR TERMINAL': 'USW00024131',
#  b'BOMNAK': 'RSM00031253',
#  b'BOR': 'RSM00023884',
#  b'BOROMO': 'UV000065516',
#  b'BORZJA': 'RSM00030965',
#  b'BOURGES AERODROME': 'FR000007255',
#  b'BRATSK': 'RSM00030309',
#  b'BROHOVO': 'RSM00025927',
#  b'BROKEN HILL (PATTON STREET)': 'ASN00047007',
#  b'BROOME AIRPORT': 'ASN00003003',
#  b'BUHTA PROVIDENJA': 'RSM00025594',
#  b'BULAWAYO (GOETZ OBS': 'ZI000067964',
#  b'BULGAN': 'MG000044239',
#  b'BURKETOWN AIRPORT': 'ASN00029077',
#  b'BURLINGTON INTL AP': 'USW00014742',
#  b'BYRD STATION': 'AYM00089324',
#  b'CABO SAN ANTONIO   PINAR DEL': 'CUM00078310',
#  b'CABRAMURRA SMHEA': 'ASN00072091',
#  b'CAIRNS POST OFFICE': 'ASN00031010',
#  b'CALI/ALFONSO BONILL': 'CO000080259',
#  b'CALVINIA': 'SF001344780',
#  b'CAMAGUEY  CAMAGUEY': 'CUM00078355',
#  b'CAMBORNE': 'UK000003808',
#  b'CAMBRIDGE BAY GSN': 'CA002400602',
#  b'CAMPBELL ISLAND AWS': 'NZ000939450',
#  b'CAPE BORDA': 'ASN00022823',
#  b'CAPE BRUNY LIGHTHOUSE': 'ASN00094010',
#  b'CAPE DORSET CLIMATE': 'CA002400636',
#  b'CAPE HATTERAS AP': 'USW00093729',
#  b'CAPE LEEUWIN': 'ASN00009518',
#  b'CAPE OTWAY LIGHTHOUSE': 'ASN00090015',
#  b'CAPE TOWN INTL': 'SFM00068816',
#  b'CAPO BELLAVISTA': 'IT000016550',
#  b'CARAVELAS': 'BR058514530',
#  b'CARIBOU MUNI AP': 'USW00014607',
#  b'CARNARVON AIRPORT': 'ASN00006011',
#  b'CARSANGA': 'TX000038915',
#  b'CARTWRIGHT': 'CA008501100',
#  b'CASA BLANCA   LA HABANA': 'CUM00078325',
#  b'CASEY': 'AYM00089611',
#  b'CEDUNA POST OFFICE': 'ASN00018011',
#  b'CENTRO MET. ANTARTICO PDTE. E': 'AYM00089056',
#  b'CERES AERO': 'AR000087257',
#  b'CHARA': 'RSM00030372',
#  b'CHARANA': 'BL000085230',
#  b'CHARLESTON INTL AP': 'USW00013880',
#  b'CHARLEVILLE AERO': 'ASN00044021',
#  b'CHATTANOOGA LOVELL AP': 'USW00013882',
#  b"CHERDYN'": 'RSM00023914',
#  b'CHERRAPUNJI': 'IN014020800',
#  b'CHIANG RAI': 'TH000048303',
#  b'CHICHIJIMA': 'JA000047971',
#  b'CHIHUAHUA  CHIH.': 'MXM00076225',
#  b'CHILEKA': 'MI000067693',
#  b'CHIPATA': 'ZA000067581',
#  b'CHIPINGE': 'ZI000067983',
#  b'CHITA': 'RSM00030758',
#  b'CHOIBALSAN': 'MG000044259',
#  b'CHOIX': 'MX000025017',
#  b'CHOKURDAH': 'RSM00021946',
#  b'CHOSHI': 'JA000047648',
#  b'CHRISTMAS ISLAND AE': 'KT000096995',
#  b'CHUMPHON': 'TH000048517',
#  b'CHUNGGANG': 'KNM00047014',
#  b'CHURCHILL CLIMATE': 'CA005060608',
#  b'CHUUK WSO AP': 'FMW00040505',
#  b'CILACAP': 'ID000096805',
#  b'CIMBAJ': 'UZM00038262',
#  b'CLAYTON MUNI AIR PK': 'USW00023051',
#  b'CLYDE RIVER CLIMATE': 'CA002400802',
#  b'COARI': 'BRM00082425',
#  b'COBAR MO': 'ASN00048027',
#  b'COBIJA': 'BL000085041',
#  b'COCHABAMBA': 'BL000085223',
#  b'COCOS ISLAND AERO': 'CK000096996',
#  b'COL DU GRAND ST-BERNARD': 'SZ000006717',
#  b'COLD BAY AP': 'USW00025624',
#  b'COLD LAKE A': 'CA003081680',
#  b'COLOMBO': 'CEM00043466',
#  b'COLONIA JUAN CARRAS': 'MX000076458',
#  b'COLUMBIA RGNL AP': 'USW00003945',
#  b'COMODORO RIVADAVIA': 'AR000087860',
#  b'CONCORDIA': 'AYM00089625',
#  b'CONCORDIA MUNI AP': 'USW00013984',
#  b'CORAL HARBOUR A': 'CA002301000',
#  b'CORDOBA AERO': 'AR000087344',
#  b'CORDOBA AEROPUERTO': 'SP000008410',
#  b'CORFU': 'GR000016641',
#  b'CRUZEIRO DO SUL': 'BR000082704',
#  b'CUIABA': 'BR000083361',
#  b'CUNDERDIN AIRFIELD': 'ASN00010286',
#  b'CURICO': 'CI000085629',
#  b'CURITIBA': 'BR002549075',
#  b'DAKAR/YOFF': 'SG000061641',
#  b'DAL BANDIN': 'PK000041712',
#  b'DALANZADGAD': 'MG000044373',
#  b'DALNERECHENSK': 'RSM00031873',
#  b'DALTONGANJ': 'IN004091000',
#  b'DANANG INTL': 'VMM00048855',
#  b'DANIELS HARBOUR': 'CA008401400',
#  b'DANMARKSHAVN': 'GL000004320',
#  b'DAR ES SALAAM AIRPO': 'TZ000063894',
#  b'DARJEELING': 'IN024050100',
#  b'DARWIN AIRPORT': 'ASN00014015',
#  b'DAUPHIN CS': 'CA005040681',
#  b'DAVIS': 'AYM00089571',
#  b'DAWSON A': 'CA002100402',
#  b'DE BILT-1': 'NLM00006260',
#  b'DEAAR(UA)': 'SFM00068538',
#  b'DEASE LAKE (AUT)': 'CA00119BLM0',
#  b'DEESA': 'IN005030100',
#  b'DENILIQUIN AIRPORT AWS': 'ASN00074258',
#  b'DERBENT': 'RSM00037470',
#  b'DES MOINES INTL AP': 'USW00014933',
#  b'DIKSON': 'RSM00020674',
#  b'DODGE CITY': 'USW00013985',
#  b'DODOMA': 'TZ000063862',
#  b'DOHA INTL': 'QAM00041170',
#  b'DOME C II': 'AYM00089828',
#  b'DOME PLATEAU DOME A': 'AYM00089577',
#  b'DONGOLA': 'SU000062650',
#  b'DORI': 'UV000065501',
#  b'DUBBO AIRPORT AWS': 'ASN00065070',
#  b'DUDINKA': 'RSM00023074',
#  b'DULAN': 'CHM00052836',
#  b"DUMONT D'URVILLE": 'AYM00089642',
#  b'DWARKA': 'IN005090100',
#  b'DZAOUDZI PAMANDZI': 'MFM00067005',
#  b'DZARDZAN': 'RSM00024143',
#  b'EAST LONDON': 'SF000068858',
#  b'EAST SALE AIRPORT': 'ASN00085072',
#  b'EKATERINO-NIKOLSKOE': 'RSM00031707',
#  b'EKIMCHAN': 'RSM00031329',
#  b'EL FASHER': 'SU000062760',
#  b'EL PASO INTL AP': 'USW00023044',
#  b'EL-GOLEA': 'AG000060590',
#  b'ELAT-1': 'IS000009972',
#  b'ELATMA': 'RSM00027648',
#  b'ELY YELLAND FLD AP': 'USW00023154',
#  b'EN NAHUD': 'SU000062781',
#  b'ENCARNACION': 'PA000086297',
#  b'ENISEJSK': 'RSM00029263',
#  b'ENMUVEEM': 'RSM00025356',
#  b'ENNADAI LAKE (AUT)': 'CA002301102',
#  b'ERBOGACEN': 'RSM00024817',
#  b'ERDENETSAGAAN': 'MG000044317',
#  b'ERENHOT': 'CHM00053068',
#  b'ERSOV': 'RSM00034186',
#  b'ESENGYLY': 'TX000038750',
#  b'ESKDALEMUIR': 'UK000003162',
#  b'ESPERANCE': 'ASN00009789',
#  b'ESQUEL AERO': 'AR000087803',
#  b'EST.MET.ARTIGAS': 'UY000086330',
#  b'ESTEVAN A': 'CA004012400',
#  b'ESTEVAN POINT CS': 'CA001032731',
#  b'EUREKA': 'CA002401200',
#  b'EUREKA WFO WOODLEY ISLAND': 'USW00024213',
#  b'EVANSVILLE REGIONAL AP': 'USW00093817',
#  b'FAIRBANKS INTL AP': 'USW00026411',
#  b'FAYA': 'CD000064753',
#  b'FERRELL': 'AYM00089872',
#  b'FINIKE': 'TU000017375',
#  b'FOKSTUA': 'NOM00001238',
#  b'FORREST': 'ASN00011052',
#  b'FORT MCMURRAY CS': 'CA003062696',
#  b'FORT NELSON A': 'CA001192940',
#  b'FORT RELIANCE (AUT)': 'CA002201903',
#  b'FORT SIMPSON CLIMATE': 'CA002202102',
#  b'FORT SMITH CLIMATE': 'CA002202202',
#  b'FOSSIL BLUFF': 'AYM00089065',
#  b'FRESNO YOSEMITE INTL AP': 'USW00093193',
#  b'FT SMITH RGNL AP': 'USW00013964',
#  b'FUNAFUTI INTL ARPT': 'TV000091643',
#  b'FUNCHAL': 'PO000008522',
#  b'GABES': 'TS000060765',
#  b'GANDER AIRPORT CS': 'CA008401705',
#  b'GANZHOU': 'CHM00057993',
#  b'GARISSA': 'KE000063723',
#  b'GAUHATI': 'IN003041800',
#  b'GEN. SANTOS': 'RP000098851',
#  b'GENINA': 'SU000062770',
#  b'GEORGE AIRPORT': 'SF000288380',
#  b'GEORGETOWN AIRPORT': 'ASN00030124',
#  b'GERALDTON AIRPORT': 'ASN00008051',
#  b'GILES METEOROLOGICAL OFFICE': 'ASN00013017',
#  b'GILL': 'AYM00089376',
#  b'GISBORNE AERODROME': 'NZ000093292',
#  b'GJOA HAVEN CLIMATE': 'CA002302340',
#  b'GLADSTONE RADAR': 'ASN00039123',
#  b'GLASGOW INTL AP': 'USW00094008',
#  b'GLEBA CELESTE': 'BRM00083264',
#  b'GMO IM.E.K.FEDOROVA': 'RSM00020292',
#  b'GOBABEB': 'WA006490640',
#  b'GOOSE A': 'CA008501900',
#  b'GORE': 'ET000063403',
#  b'GORE BAY CLIMATE': 'CA006092920',
#  b'GOTSKA SANDON A': 'SWM00002589',
#  b'GOUGH ISLAND': 'SHM00068906',
#  b'GOVE AIRPORT': 'ASN00014508',
#  b'GRAND JUNCTION WALKER FLD': 'USW00023066',
#  b'GRANTLEY ADAMS': 'BB000078954',
#  b'GREER': 'USW00003870',
#  b'GROOTFONTEIN': 'WA010101860',
#  b'GRYTVIKEN': 'SXM00088903',
#  b'GUADALCANAL AAF': 'BPW00080601',
#  b'GUALEGUAYCHU': 'ARM00087497',
#  b'GUAM INTL AP': 'GQW00041415',
#  b'GUANAJUATO': 'MX000076577',
#  b'GUANGZHOU': 'CHM00059287',
#  b'GUIRIA': 'VE000080423',
#  b'GYZYLARBAT': 'TX000038763',
#  b'H4': 'JOM00040250',
#  b'HACIENDA YLANG YLANG VERACRUZ': 'MXM00076692',
#  b'HAIKOU': 'CHM00059758',
#  b'HAIL': 'SA000403940',
#  b'HAILAR': 'CHM00050527',
#  b'HALL BEACH CLIMATE': 'CA002402353',
#  b'HALLEY': 'AYM00089022',
#  b'HALLS CREEK AIRPORT': 'ASN00002012',
#  b'HAMBANTOTA': 'CE000043497',
#  b'HAMBURG FUHLSBUETTEL': 'GM000010147',
#  b'HAMI': 'CHM00052203',
#  b'HANAN AIRPORT': 'NEM00091824',
#  b'HANTY-MANSIJSK': 'RSM00023933',
#  b'HAPARANDA_A': 'SWE00140622',
#  b'HARARE (KUTSAGA)': 'ZI000067775',
#  b'HARRINGTON CDA CS': 'CA00830P001',
#  b'HARRY': 'AYM00089329',
#  b'HATANGA': 'RSM00020891',
#  b'HAY RIVER CLIMATE': 'CA002202402',
#  b'HELENA RGNL AP': 'USW00024144',
#  b'HELWAN': 'EGM00062378',
#  b'HEREHERETUE': 'FPM00091945',
#  b'HIGH LEVEL': 'CA003073140',
#  b'HIHIFO (ILE WALLIS)': 'WF000917530',
#  b'HILO INTL AP': 'USW00021504',
#  b'HINATUAN': 'RP000098755',
#  b'HIVA-OA': 'FP000091925',
#  b'HOHENPEISSENBERG': 'GM000010962',
#  b'HOLMAN CS': 'CA002502505',
#  b'HOLMON A': 'SWE00140178',
#  b'HOMER AP': 'USW00025507',
#  b'HON': 'LY000062131',
#  b'HORTA (AZORES)': 'PO000008506',
#  b'HOTAN': 'CHM00051828',
#  b'HOVD': 'MG000044218',
#  b'HURGUADA': 'EG000062463',
#  b'HURON RGNL AP': 'USW00014936',
#  b'HYDERABAD AIRPORT': 'PKM00041764',
#  b'ILE EUROPA': 'EUM00061972',
#  b'ILIRNEJ': 'RSM00025248',
#  b'IM. POLINY OSIPENKO': 'RSM00031416',
#  b'IMPFONDO': 'CF000064459',
#  b'IN-AMENAS': 'AG000060611',
#  b'INCHEON': 'KS000047112',
#  b'INHAMBANE': 'MZ000067323',
#  b'INUKJUAK UA': 'CA007103282',
#  b'INUVIK CLIMATE': 'CA002202578',
#  b'INVERCARGILL AIRPOR': 'NZ000093844',
#  b'INVERELL (RAGLAN ST)': 'ASN00056242',
#  b'IQALUIT CLIMATE': 'CA002402592',
#  b'IQUITOS': 'PE000084377',
#  b'IRKUTSK': 'RSM00030710',
#  b'IRTYSHSK': 'KZ000029807',
#  b'ISACHSEN (AUT)': 'CA002402604',
#  b'ISLA DE PASCUA': 'CI000085469',
#  b'ISLE AUX MORTS': 'CA008402450',
#  b'ISPARTA': 'TU000017240',
#  b'ISTANBUL': 'TU000017062',
#  b'IZANA': 'SP000060010',
#  b'IZOBAMBA': 'ECM00084088',
#  b'J.G.H. VAN DER WATH AIRP': 'WA004191820',
#  b'JACHAL': 'AR000873050',
#  b'JAGDALPUR': 'IN011020300',
#  b'JAKARTA/OBSERVATORY': 'ID000096745',
#  b'JAKUTSK': 'RSM00024959',
#  b'JAN MAYEN': 'JNM00001001',
#  b'JASKUL': 'RSM00034866',
#  b'JAYAPURA/SENTANI': 'ID000097690',
#  b'JEDDAH (KING ABDUL': 'SA000041024',
#  b'JENDOUBA': 'TS000060725',
#  b'JIUQUAN': 'CHM00052533',
#  b'JOKIOINEN JOKIOISTEN OBSERVATO': 'FI000002963',
#  b'JOMO KENYATTA INTL': 'KE000063740',
#  b'JUAN FERNANDEZ': 'CI000085585',
#  b'JUBA': 'SU000062941',
#  b'JUBILEJNAJA': 'RSM00021931',
#  b'JUZHNO-SAHALINSK': 'RSM00032150',
#  b'JYVASKYLA LENTOASEMA': 'FI000002401',
#  b'KALGOORLIE-BOULDER AIRPORT': 'ASN00012038',
#  b'KALUMBURU': 'ASN00001019',
#  b'KAMENSKOE': 'RSM00025745',
#  b'KAMISHLI': 'SY000040001',
#  b'KAMLOOPS AUT': 'CA001163842',
#  b'KANDALAKSA': 'RSM00022217',
#  b'KANDI': 'BN000065306',
#  b'KANIN NOS': 'RSM00022165',
#  b'KAPUSKASING CDA ON': 'CA006073980',
#  b'KARAGANDA': 'KZ000035394',
#  b'KASAMA': 'ZA000067475',
#  b'KASHI': 'CHM00051709',
#  b'KASSALA': 'SU000062730',
#  b'KASTAMONU': 'TU000017074',
#  b'KATHMANDU AIRPORT': 'NP000444540',
#  b'KAZALINSK': 'KZ000035849',
#  b'KAZAN': 'RSM00027595',
#  b'KEM-PORT': 'RSM00022520',
#  b'KENDARI/WOLTER MONG': 'ID000097146',
#  b'KENITRA PORT LYAUTEY': 'MOW00013017',
#  b'KERMAN': 'IR000040841',
#  b'KERMANSHAH': 'IR000407660',
#  b'KEY WEST INTL AP': 'USW00012836',
#  b'KHARGA': 'EGM00062435',
#  b'KHOROG': 'TI000038954',
#  b'KIMBERLEY': 'SF000068438',
#  b'KING ABDULLAH BIN ABDULAZIZ': 'SAM00041140',
#  b'KING SALMON': 'USW00025503',
#  b'KING SHAKA INTL AIRPORT': 'SFM00068592',
#  b'KIRENSK': 'RSM00030230',
#  b'KIRS': 'RSM00028009',
#  b'KISINEV': 'MD000033815',
#  b'KITA': 'ML000061270',
#  b'KITADAITO': 'JA000047945',
#  b'KITALE': 'KE000063661',
#  b'KJAHTA': 'RSM00030925',
#  b'KJUSJUR': 'RSM00021921',
#  b'KLJUCHI': 'RSM00032389',
#  b'KODAIKANAL': 'IN020081000',
#  b'KOEBENHAVN: LANDBOHOJSKOLEN-1': 'DA000030380',
#  b'KOKPEKTY': 'KZ000036535',
#  b'KOLPASEVO': 'RSM00029231',
#  b'KOROR WSO': 'PSW00040309',
#  b'KOSCH-AGACH': 'RSM00036259',
#  b'KOTZEBUE RALPH WEIN AP': 'USW00026616',
#  b'KOUMAC (NLLE-CALEDO': 'NC000091577',
#  b'KRASNODAR': 'RSM00034927',
#  b'KRASNOJARSK': 'RSM00029570',
#  b'KREMSMUENSTER': 'AU000005010',
#  b'KUANTAN': 'MY000048657',
#  b'KUCHING': 'MY000096413',
#  b'KUFRA': 'LY000062271',
#  b'KUGAARUK CLIMATE': 'CA002303094',
#  b'KUGLUKTUK CLIMATE': 'CA002300904',
#  b'KUPANG/ELTARI': 'ID000097372',
#  b'KURGAN-TYUBE': 'TI000038933',
#  b'KUSTANAI': 'KZ000028952',
#  b'KUT-AL-HAI': 'IZ000040665',
#  b'KUUJJUAQ A': 'CA007113534',
#  b'KUWAIT INTERNATIONA': 'KU000405820',
#  b'KWAJALEIN': 'RMW00040604',
#  b'KYRA': 'RSM00030949',
#  b'L F WADE INTL AP KINDLEY FLD': 'BDM00078016',
#  b'LA GRANDE IV': 'CA007093GJ5',
#  b'LA GRANDE RIVIERE A': 'CA007093715',
#  b'LA ORCHILA': 'VE000080405',
#  b'LA PAZ (CITY)': 'MX000003074',
#  b'LA PLATA': 'ARM00087593',
#  b'LA POCATIERE': 'CA007054096',
#  b'LA QUIACA OBSERVATO': 'AR000087007',
#  b'LA RIOJA AERO.': 'AR000087217',
#  b'LA RONGE RCS': 'CA004064149',
#  b'LA SERENA': 'CI000085488',
#  b'LABOULAYE AERO': 'AR000087534',
#  b'LABUAN': 'MY000096465',
#  b'LAHORE CITY': 'PK000041640',
#  b'LANDER HUNT FLD AP': 'USW00024021',
#  b'LANZAROTE/AEROPUERTO': 'SP000060040',
#  b'LARNACA': 'CY000176090',
#  b'LAS LOMITAS': 'AR000087078',
#  b'LAS VEGAS MCCARRAN AP': 'USW00023169',
#  b'LATTAKIA': 'SY000040022',
#  b'LAZAROPOLE': 'MK000013577',
#  b'LE RAIZET, GUADELOUPE': 'GP000078897',
#  b'LEARMONTH AIRPORT': 'ASN00005007',
#  b'LEBA': 'PL000012120',
#  b'LEGASPI': 'RP000098444',
#  b'LERWICK': 'UK000003005',
#  b'LETTAU': 'AYM00089377',
#  b'LEUSI': 'RSM00028064',
#  b'LEXINGTON BLUEGRASS AP': 'USW00093820',
#  b'LHASA': 'CHM00055591',
#  b'LIEPAJA': 'LG000026406',
#  b'LIHUE WSO AP 1020.1': 'USW00022536',
#  b'LINDENBERG': 'GM000010393',
#  b'LISBOA GEOFISICA': 'PO000008535',
#  b'LIVINGSTONE': 'ZA000067743',
#  b'LODWAR': 'KE000063612',
#  b'LOJA/LA ARGELIA': 'ECM00084270',
#  b'LONGREACH AERO': 'ASN00036031',
#  b'LORD HOWE ISLAND AERO': 'ASM00094995',
#  b'LOW HEAD': 'ASN00091293',
#  b'LUANDA': 'AO000066160',
#  b'LUBANGO (SA DA BAND': 'AO000066390',
#  b'LUBNY': 'UPM00033377',
#  b'LUNGI': 'SL000061856',
#  b'LUQA': 'MT000016597',
#  b'LUXEMBOURG AIRPORT': 'LU000006590',
#  b"MA'AN": 'JOM00040310',
#  b'MACKAY M.O': 'ASN00033119',
#  b'MACMILLAN PASS': 'CA002100693',
#  b'MACQUARIE ISLAND': 'ASM00094998',
#  b'MADRAS/MINAMBAKKAM': 'IN020040900',
#  b'MAFIKENG': 'SFM00068242',
#  b'MAGDALENA': 'BL000085114',
#  b'MAINE-SOROA': 'NG000061096',
#  b'MAINTIRANO': 'MAM00067073',
#  b'MAJURO WBAS AP': 'RMW00040710',
#  b'MALARGUE': 'ARM00087506',
#  b'MALE': 'MV000043555',
#  b'MALIN HEAD': 'EI000003980',
#  b'MALIYE_KARMAKULY': 'RSM00020744',
#  b'MALKAL': 'SU000062840',
#  b'MANANJARY': 'MA000067143',
#  b'MANAUS': 'BRM00082331',
#  b'MANDALAY': 'BMM00048042',
#  b'MANDALGOBI': 'MG000044341',
#  b'MANDERA': 'KE000063624',
#  b'MANGAREVA': 'FP000091948',
#  b'MANGO/SANSANNE': 'TOM00065352',
#  b'MANIWAKI AIRPORT': 'CA007034482',
#  b'MANZANILLO': 'MX000076654',
#  b'MAR DEL PLATA AERO': 'AR000087692',
#  b'MARBLE POINT': 'AYW00087602',
#  b'MARIGNANE AEROPORT MARSEILLE M': 'FR000007650',
#  b'MARILYN': 'AYM00089869',
#  b'MARION ISLAND': 'SF000068994',
#  b'MARKOVO': 'RSM00025551',
#  b'MARQUETTE': 'USW00014838',
#  b'MARREE COMPARISON': 'ASN00017031',
#  b'MARTIN DE VIVIES (I': 'FSM00061996',
#  b'MASHHAD': 'IR000040745',
#  b'MASIRAH': 'MU000041288',
#  b'MATARAM-LOMBOK INTL AIRPORT': 'IDM00097240',
#  b'MAUN': 'BC000068032',
#  b'MAVINGA': 'AO000066447',
#  b'MAWSON': 'AYM00089564',
#  b'MCGRATH AP': 'USW00026510',
#  b'MCMURDO SOUND NAF': 'AYM00089664',
#  b'MEDICINE HAT RCS': 'CA003034485',
#  b'MEEKATHARRA AIRPORT': 'ASN00007045',
#  b'MELILLA': 'SP000060338',
#  b'MELO': 'UY000001709',
#  b'MENADO/ SAM RATULAN': 'ID000097014',
#  b'MENAKA': 'ML000061250',
#  b'MENDOZA AERO': 'AR000087418',
#  b'MENE GRANDE': 'VE000080425',
#  b'MENGZI': 'CHM00056985',
#  b'MENONGUE (SERPA PIN': 'AO000066410',
#  b'MERAUKE/MOPAH': 'ID000097980',
#  b'MERCEDES': 'UY000086490',
#  b'MERIDA': 'VE000080438',
#  b'MERIDIAN KEY FLD': 'USW00013865',
#  b'MERSA MATRUH': 'EG000062306',
#  b'METEHARA': 'ET000063453',
#  b'METHONI': 'GR000016734',
#  b'MEXICO CITY': 'MX000766800',
#  b'MEZEN': 'RSM00022471',
#  b'MIDELT': 'MO000060195',
#  b'MILDURA AIRPORT': 'ASN00076031',
#  b'MILESOVKA': 'EZ000011464',
#  b'MINAMI TORI SHIMA MA': 'JA000047991',
#  b'MINDELO': 'CVM00008583',
#  b'MINICOY         OBSY': 'IN025010100',
#  b'MINNA': 'NIM00065123',
#  b'MINNEAPOLIS/ST PAUL AP': 'USW00014922',
#  b'MINUSINSK': 'RSM00029866',
#  b'MIRNYJ': 'AYM00089592',
#  b'MITT. UPERNAVIK': 'GLE00146908',
#  b'MOCAMEDES': 'AO000066422',
#  b'MOGOCA': 'RSM00030673',
#  b'MOKPO': 'KS000047165',
#  b'MOMBASA': 'KE000063820',
#  b'MOMOTE W.O.': 'PPM00092044',
#  b'MONGU': 'ZA000067633',
#  b'MONT-AIGOUAL': 'FR000007560',
#  b'MONTE CIMONE': 'IT000016134',
#  b'MONTE S. ANGELO': 'IT000162580',
#  b'MONTEGO BAY/SANGSTE': 'JM000078388',
#  b'MONTERREY (CITY)': 'MX000076393',
#  b'MOOSONEE RCS': 'CA006075435',
#  b'MORUYA HEADS PILOT STATION': 'ASN00069018',
#  b'MOSCOW': 'RSM00027612',
#  b'MOULD BAY CS': 'CA00250M001',
#  b'MOUNDOU': 'CD000064706',
#  b'MOUNT GAMBIER POST OFFICE': 'ASN00026020',
#  b'MOUNT ISA MINE': 'ASN00029126',
#  b'MOUNT PLEASANT': 'FKM00088889',
#  b'MOUNT SIPLE': 'AYM00089327',
#  b'MT WASHINGTON': 'USW00014755',
#  b'MUNDA': 'BP000091503',
#  b'MUREN': 'MG000044231',
#  b'MURMANSK': 'RSM00022113',
#  b'MUYINGA': 'BY000064397',
#  b'MWINILUNGA': 'ZA000067441',
#  b'MYS SHMIDTA': 'RSM00025173',
#  b'MYS UELEN': 'RSM00025399',
#  b'NADI AIRPORT': 'FJ000091680',
#  b'NAGASAKI': 'JA000047817',
#  b'NAHA': 'JA000047936',
#  b'NAIN': 'CA008502799',
#  b'NAKHON SAWAN': 'TH000048400',
#  b'NANCHANG': 'CHM00058606',
#  b'NANNING': 'CHM00059431',
#  b'NANUMEA': 'TV000091631',
#  b'NARJAN MAR': 'RSM00023205',
#  b'NARYN': 'KG000036974',
#  b'NASSAU AIRPORT NEW': 'BF000078073',
#  b'NATASHQUAN A': 'CA007045401',
#  b'NAVACERRADA': 'SP000008215',
#  b'NDJAMENA': 'CD000004700',
#  b'NEGHELLE': 'ET000063533',
#  b'NEMA': 'MR000061497',
#  b'NEMURO': 'JA000047420',
#  b'NERCHINSKIJ ZAVOD': 'RSM00030879',
#  b'NEUMAYER': 'AYM00089002',
#  b'NEUQUEN AERO': 'AR000087715',
#  b'NEW DELHI/SAFDARJUN': 'IN022021900',
#  b'NEW ORLEANS INTL AP': 'USW00012916',
#  b'NEW PLYMOUTH AWS': 'NZ000933090',
#  b'NEWMAN AERO': 'ASN00007176',
#  b'NGAOUNDERE': 'CM000064870',
#  b'NIKOLAEVSK-NA-AMURE': 'RSM00031369',
#  b'NIKOLSKOYE/BERINGA OSTROV': 'RSM00032618',
#  b'NIZHNEANGARSK': 'RSM00030433',
#  b'NJAKSIMVOL': 'RSM00023724',
#  b'NOME MUNI AP': 'USW00026617',
#  b'NORFOLK ISLAND INTL': 'NFM00094996',
#  b'NORFOLK KARL STEFAN AP': 'USW00014941',
#  b'NORMAN WELLS CLIMATE': 'CA002202810',
#  b'NORTH PLATTE RGNL AP': 'USW00024023',
#  b'NORTH-SALANG': 'AF000040930',
#  b'NOUADHIBOU': 'MR000061415',
#  b'NOUMEA (NLLE-CALEDO': 'NC000915920',
#  b'NOVOLAZAREVSKAJA': 'AYM00089512',
#  b'NUUK': 'GL000004250',
#  b'NUWARA ELIYA': 'CE000434730',
#  b'OESTERSUND': 'SWE00100026',
#  b'OHOTSK': 'RSM00031088',
#  b'OITA': 'JA000047815',
#  b'OJMJAKON': 'RSM00024688',
#  b'OKLAHOMA CITY WILL ROGERS AP': 'USW00013967',
#  b'OKTJABRSKIJ-GORODOK': 'RSM00034163',
#  b'OLENEK': 'RSM00024125',
#  b'OLYMPIA AP': 'USW00024227',
#  b'OMSK': 'RSM00028698',
#  b'ONA HUSOY': 'NO000001212',
#  b'ONO-I-LAU AWS': 'FJM00091699',
#  b'OODNADATTA AIRPORT': 'ASN00017043',
#  b'OSTROV GOLOMJANNYJ': 'RSM00020087',
#  b'OSTROV KOTELNYJ': 'RSM00021432',
#  b'OSTROV VIZE': 'RSM00020069',
#  b'OSTROV VRANGELJA': 'RSM00021982',
#  b'OUARZAZATE': 'MO000060265',
#  b'PADANG/TABING': 'ID000096163',
#  b'PAGANELLA': 'IT000160220',
#  b'PAGO PAGO WSO AP': 'AQW00061705',
#  b'PALMYRA': 'SY000040061',
#  b'PAMBAN': 'IN020100400',
#  b'PANGNIRTUNG': 'CA002403049',
#  b'PARACHINAR': 'PK000041560',
#  b'PARANA AERO': 'AR000087374',
#  b'PARAPARAUMU AWS': 'NZ000093417',
#  b'PASNI': 'PKM00041759',
#  b'PASO DE LOS LIBRES': 'ARM00087289',
#  b'PASTO/ANTONIO NARIN': 'CO000080342',
#  b'PAULATUK': 'CA002203058',
#  b'PEAWANUCK (AUT)': 'CA006016295',
#  b'PECS POGANY': 'HU000012942',
#  b'PEHUAJO AERO': 'AR000875440',
#  b'PEKOA AIRPORT (SANT': 'NH000091554',
#  b'PEMBA': 'MZ000067215',
#  b'PENDLETON': 'USW00024155',
#  b'PENDRA ROAD': 'IN011060800',
#  b'PEORIA GTR PEORIA AP': 'USW00014842',
#  b'PERM': 'RSM00028224',
#  b'PHOENIX SKY HARBOR INTL AP': 'USW00023183',
#  b'PICHILINGUE': 'EC000000006',
#  b'PITCAIRN ISLAND C': 'PC000919640',
#  b'PITTSBURGH INTL AP': 'USW00094823',
#  b'PLAISANCE (MAURITIU': 'MP000061990',
#  b'POCATELLO RGNL AP': 'USW00024156',
#  b'PODOR': 'SG000061612',
#  b'POHNPEI WSO': 'FMW00040504',
#  b'POLAR GMO IM.E.T.KRENKELJ': 'RSM00020046',
#  b'POLOKWANE': 'SFM00068174',
#  b'POND INLET CLIMATE': 'CA002403204',
#  b'PONTA DELGADA': 'POM00008512',
#  b'PONTE DA BR-040 - PRATA': 'BR001746006',
#  b'POONA': 'IN012190100',
#  b'POPRAD/TATRY': 'LO000011934',
#  b'PORONAJSK': 'RSM00032098',
#  b'PORT BLAIR': 'IN099999901',
#  b'PORT ELIZABETH INTL': 'SFM00068842',
#  b'PORT HARDY A': 'CA001026270',
#  b'PORT HEDLAND AIRPORT': 'ASN00004032',
#  b'PORT MORESBY W.O.': 'PP000092035',
#  b'PORT SUDAN': 'SU000062641',
#  b'PORT-AUX-FRANCAIS (ILES KERGU': 'FRM00061998',
#  b'PORTO NACIONAL': 'BRM00083064',
#  b'POSADAS': 'ARM00087178',
#  b'POSSESSION IS': 'AYM00089879',
#  b'PRACHUAP KHIRI KHAN': 'TH000048500',
#  b'PRETORIA(MET)': 'SFM00068262',
#  b'PRINCE ALBERT A': 'CA004056240',
#  b'PRINS CHRISTIAN': 'GLM00004390',
#  b'PROGRESS': 'AYM00089574',
#  b'PUERTO CASADO': 'PA000086086',
#  b'PUERTO LIMON': 'CS000081003',
#  b'PUERTO MONTT': 'CI000085799',
#  b'PUNTA ARENAS': 'CI000085934',
#  b'PUNTA DE MAISI   GUANTANAMO': 'CUM00078369',
#  b'PUSKINSKIE_GORY': 'RSM00026359',
#  b'QAMDO': 'CHM00056137',
#  b'QIKIQTARJUAQ CLIMATE': 'CA002400573',
#  b'QINGDAO': 'CHM00054857',
#  b'QIQIHAR': 'CHM00050745',
#  b'QUELIMANE': 'MZ000067283',
#  b'QUESNEL AIRPORT AUTO': 'CA001096631',
#  b'QUINTERO': 'CI000085543',
#  b'QUIXERAMOBIM': 'BR038014410',
#  b'RABBIT FLAT': 'ASN00015548',
#  b'RALEIGH DURHAM INTL AP': 'USW00013722',
#  b'RAPA': 'FP000091958',
#  b'RAROTONGA INTL': 'CWM00091843',
#  b'RECONQUISTA AERO': 'AR000087270',
#  b'RELAY STAT': 'AYM00089744',
#  b'RENNES': 'FR000007130',
#  b'RESISTENCIA AERO': 'AR000087155',
#  b'RESOLUTE CS': 'CA002403505',
#  b'REYKJAVIK': 'IC000004030',
#  b'RHEIN MAIN': 'GMW00035032',
#  b'RIBERALTA': 'BL000085043',
#  b'RICHMOND POST OFFICE': 'ASN00030045',
#  b'RICHMOND RAAF': 'ASN00067033',
#  b'RIO GALLEGOS AERO': 'AR000087925',
#  b'RIVADAVIA': 'AR000087065',
#  b'RIVIERE AUX FEUILLES': 'CA007116505',
#  b'RIYADH OBS. (O.A.P.': 'SA000040438',
#  b'RIZE': 'TU000017040',
#  b'ROBERTS': 'CJW00011813',
#  b'ROBERTSON LAKE (AUT)': 'CA002303610',
#  b'ROCHA': 'UY000086565',
#  b'ROCHAMBEAU': 'FG000081405',
#  b'RODRIGUES': 'MP000061988',
#  b'ROTHERA': 'AYM00089062',
#  b'ROTUMA': 'FJ000091650',
#  b'RUOQIANG': 'CHM00051777',
#  b'RURRENABAQUE': 'BL000085141',
#  b'S.A.N.A.E. AWS': 'AYM00089004',
#  b'SABLE ISLAND': 'CA008204700',
#  b'SACHS HARBOUR CLIMATE': 'CA002503648',
#  b'SACRAMENTO EXECUTIVE AP': 'USW00023232',
#  b'SAENTIS': 'SZ000002220',
#  b'SAGAR': 'IN011330900',
#  b'SAIQ': 'MU000041254',
#  b'SALALAH': 'MUM00041316',
#  b'SALAMANCA AEROPUERTO': 'SP000008202',
#  b'SALEKHARD': 'RSM00023330',
#  b'SALINA CRUZ': 'MX000768330',
#  b'SALTA AERO': 'AR000870470',
#  b'SALVADOR': 'BR048620980',
#  b'SAM': 'KZ000035925',
#  b'SAMOS AIRPORT': 'GR000167230',
#  b'SAN ANDRES (ISLA)/S': 'CO000080001',
#  b'SAN ANTONIO INTL AP': 'USW00012921',
#  b'SAN CRISTOBAL': 'ECM00084008',
#  b'SAN DIEGO LINDBERGH FLD': 'USW00023188',
#  b'SAN FERNANDO': 'VE000080450',
#  b'SAN IGNACIO VELASCO': 'BLM00085207',
#  b'SAN JUAN L M MARIN AP': 'RQW00011641',
#  b'SAN SEBASTIAN - IGUELDO': 'SP000008027',
#  b'SANDAKAN': 'MY000096491',
#  b'SANGKAPURA (BAWEAN': 'ID000096925',
#  b'SANTA ELENA DE UAIR': 'VE000080462',
#  b'SANTA ROSA AERO': 'AR000087623',
#  b'SAO GABRIEL DA CACH': 'BRM00082106',
#  b'SAO PAULO': 'BR00E3-0070',
#  b'SARAPUL': 'RSM00028418',
#  b'SASKYLAH': 'RSM00021802',
#  b'SASSANDRA': 'IV000065599',
#  b'SAUMLAKI/OLILIT': 'ID000097900',
#  b'SAVE': 'BN000065335',
#  b'SCHEFFERVILLE A': 'CA007117825',
#  b'SCIENCE GARDEN': 'RP000098430',
#  b'SEBHA': 'LY000062124',
#  b'SELAGONCY': 'RSM00024329',
#  b'SEMEJ': 'KZ000036177',
#  b'SENNAR': 'SU000062762',
#  b'SEPT-ILES': 'CA007047914',
#  b'SEYCHELLES INTERNAT': 'SE000063980',
#  b'SHADRINSK': 'RSM00028552',
#  b'SHANGHAI': 'CHM00058362',
#  b'SHANTOU': 'CHM00059316',
#  b'SHARJAH INTER. AIRP': 'AE000041196',
#  b'SHENYANG': 'CHM00054342',
#  b'SHEPETIVKA': 'UPM00033317',
#  b'SHERIDAN CO AP': 'USW00024029',
#  b'SHIMLA': 'IN007101600',
#  b'SHIMOJISHIMA': 'JA000047927',
#  b'SHIONOMISAKI': 'JA000047778',
#  b'SHIRAZ': 'IR000040848',
#  b'SHREVEPORT': 'USW00013957',
#  b'SIBOLGA/PINANGSORI': 'ID000096073',
#  b'SIEDLCE': 'PL000012385',
#  b'SIKASSO': 'ML000061297',
#  b'SIOUX LOOKOUT A': 'CA006037775',
#  b'SIPLE DOME': 'AYM00089345',
#  b'SITIAWAN': 'MY000048620',
#  b'SITTWE': 'BMM00048062',
#  b'SIVAS': 'TU000017090',
#  b'SIWA': 'EG000062417',
#  b'SLAVE LAKE AWOS A': 'CA003066002',
#  b'SMOLENSK': 'RSM00026781',
#  b'SNOWTOWN (RAYVILLE PARK)': 'ASN00021133',
#  b'SODANKYLA AWS': 'FI000007501',
#  b'SONGEA': 'TZ000063962',
#  b'SONGKHLA': 'TH000048568',
#  b'SONNBLICK': 'AU000015410',
#  b'SOROCINSK': 'RSM00035011',
#  b'SORONG/JEFMAN': 'ID000097502',
#  b'SORTAVALA': 'RSM00022802',
#  b'SOUDA AIRPORT': 'GR000167460',
#  b'SPRINGBOK': 'SF002146700',
#  b'SREDNEKAN': 'RSM00025705',
#  b'SRINAGAR': 'IN008010200',
#  b'ST GEORGE AIRPORT': 'ASN00043109',
#  b'ST PAUL ISLAND AP': 'USW00025713',
#  b'ST. BRANDON (ST. RA': 'MP000061986',
#  b'ST. HELENA IS.': 'SHM00061901',
#  b'ST. PETERSBURG': 'RSM00026063',
#  b'STEFANSSON ISLAND': 'CA002403756',
#  b'STORNOWAY AIRPORT': 'UK000003026',
#  b'STRASBOURG-ENTZHEIM': 'FR000007190',
#  b'STYKKISHOLMUR': 'IC000004013',
#  b'SULINA': 'ROM00015360',
#  b'SUNTAR': 'RSM00024738',
#  b'SVALBARD AIRPORT': 'SV000001008',
#  b'SWIFT CURRENT CDA': 'CA004028060',
#  b'SYOWA': 'AYM00089532',
#  b'SYRACUSE HANCOCK INTL AP': 'USW00014771',
#  b'TABORA AIRPORT': 'TZ000063832',
#  b'TABRIZ': 'IR000040706',
#  b'TAHITI-FAAA': 'FP000091938',
#  b'TAHOUA': 'NG000061043',
#  b'TAKAROA': 'FP000091943',
#  b'TALKEETNA AP': 'USW00026528',
#  b'TAMANRASSET': 'AG000060680',
#  b'TAMBACOUNDA': 'SG000061687',
#  b'TAMDY': 'UZM00038413',
#  b'TAMPA INTL AP': 'USW00012842',
#  b'TAN SON HOA': 'VM000048900',
#  b'TAOLAGNARO': 'MA000067197',
#  b'TARA': 'RSM00028493',
#  b'TARA HILLS': 'NZ000937470',
#  b'TARAPOTO': 'PE000084455',
#  b'TARAWA': 'KR000091610',
#  b'TAREE AIRPORT AWS': 'ASN00060141',
#  b'TAREMPA': 'ID000096145',
#  b'TARIJA': 'BL000085364',
#  b'TARKO-SALE': 'RSM00023552',
#  b'TARTU': 'EN000026242',
#  b'TASHKENT': 'UZM00038457',
#  b'TASIILAQ': 'GL000004360',
#  b'TEHRAN-MEHRABAD': 'IR000407540',
#  b'TEMUCO': 'CI000085743',
#  b'TENGCHONG': 'CHM00056739',
#  b'TENNANT CREEK AIRPORT': 'ASN00015135',
#  b'TESSALIT': 'ML000061202',
#  b'TEWANTIN RSL PARK': 'ASN00040908',
#  b'THARGOMINDAH AIRPORT': 'ASN00045025',
#  b'THE PAS CLIMATE': 'CA005052890',
#  b'THOMPSON A': 'CA005062922',
#  b'TIBOOBURRA POST OFFICE': 'ASN00046037',
#  b'TIDJIKJA': 'MR000061450',
#  b'TINDAL RAAF': 'ASN00014932',
#  b'TIRANA RINAS': 'ALM00013615',
#  b'TOAMASINA': 'MA000067095',
#  b'TOBOLSK': 'RSM00028275',
#  b'TOLIARA': 'MA000067161',
#  b'TOMBOUCTOU': 'ML000061223',
#  b'TOMPO': 'RSM00024671',
#  b'TORSHAVN': 'DAM00006011',
#  b'TORUNGEN FYR': 'NO000001465',
#  b'TOT-MA': 'RSM00027051',
#  b'TRELEW AERO': 'AR000087828',
#  b'TRIPOLI AIRPORT': 'LYE00147744',
#  b'TROICKO-PECHERSKOE': 'RSM00023711',
#  b'TROMSO': 'NO000001026',
#  b'TRUBCEVSK': 'RSM00026997',
#  b'TTE DE AV SALVADOR OGAYA G': 'BLM00085289',
#  b'TUBUAI': 'FP000091954',
#  b'TUMEREMO': 'VE000080453',
#  b'TURA': 'RSM00024507',
#  b'TURKMEN-BASHI': 'TX000038507',
#  b'TURUHANSK': 'RSM00023472',
#  b'UCCLE': 'BE000006447',
#  b'UDU POINT AWS': 'FJ000091652',
#  b'UFA': 'RSM00028722',
#  b'UIL': 'KZ000035416',
#  b'ULAAN-GOM': 'MG000044212',
#  b'ULIASTAI': 'MG000044272',
#  b'ULLEUNGDO': 'KS000047115',
#  b'UMAN': 'UPM00033587',
#  b'UNIV. WI ID 8902 (BUTLER ISLA': 'AYM00089266',
#  b'UNIV. WI ID 8917 (SKI-BLU)': 'AYM00089272',
#  b'UNIV. WI ID 8926 (LARSEN ICE': 'AYM00089262',
#  b'UPINGTON AGR.': 'SF003174470',
#  b'URALSK': 'KZ000035108',
#  b'UST TZILMA': 'RSM00023405',
#  b'UST-MAJA': 'RSM00024966',
#  b'UST-MOMA': 'RSM00024382',
#  b'UST-OLOJ': 'RSM00025325',
#  b'UST-VOJAMPOLKA': 'RSM00032252',
#  b'UTSIRA FYR': 'NO000014030',
#  b'VALENTIA OBSERVATORY': 'EI000003953',
#  b'VALLEY': 'UK000003302',
#  b'VAN': 'TU000017170',
#  b'VANAVARA': 'RSM00024908',
#  b'VARDO': 'NO000098550',
#  b'VARFU OMUL': 'ROM00015280',
#  b'VASILEVICI': 'BOM00033038',
#  b'VERHNEE PENZINO': 'RSM00025538',
#  b'VERHNEIMBATSK': 'RSM00023678',
#  b'VERHNJAJA GUTARA': 'RSM00029789',
#  b'VERHOJANSK': 'RSM00024266',
#  b'VERNADSKY': 'AYM00089063',
#  b'VESTMANNAEYJAR': 'IC000004048',
#  b'VIGNA DI VALLE': 'IT000162240',
#  b'VILJUJSK': 'RSM00024641',
#  b'VILNIUS': 'LH000026730',
#  b'VITIM': 'RSM00030054',
#  b'VLADIVOSTOK': 'RSM00031960',
#  b'VOLOCHANKA': 'RSM00020982',
#  b'VOLOGDA': 'RSM00027037',
#  b'VORONEZ': 'RSM00034123',
#  b'VOSTOK': 'AYM00089606',
#  b'VYTEGRA': 'RSM00022837',
#  b'WADDINGTON': 'UK000003377',
#  b'WADI HALFA': 'SU000062600',
#  b'WAGER BAY (AUT)': 'CA002403945',
#  b'WAGGA WAGGA AMO': 'ASN00072150',
#  b'WAINGAPU/MAU HAU': 'ID000097340',
#  b'WAJIMA': 'JA000047600',
#  b'WAKKANAI': 'JA000047401',
#  b'WAKU KUNGU (CELA)': 'AO000066270',
#  b'WAMENA': 'ID000097686',
#  b'WASHINGTON REAGAN AP': 'USW00013743',
#  b'WATSON LAKE (AUT)': 'CA002101204',
#  b'WAU': 'SU000062880',
#  b'WEIPA AERO': 'ASN00027045',
#  b'WENJIANG': 'CHM00056187',
#  b'WHITEHORSE AUTO': 'CA002101310',
#  b'WHITLOCK': 'AYM00089865',
#  b'WIDE AWAKE FIELD (A': 'SHM00061902',
#  b'WIEN': 'AU000005901',
#  b'WILLIS ISLAND': 'ASM00094299',
#  b'WINDHOEK': 'WA007401540',
#  b'WINNEMUCCA MUNI AP': 'USW00024128',
#  b'WU LU MU QI': 'CHM00051463',
#  b'XICHANG': 'CHM00056571',
#  b'YACUIBA': 'BL000085365',
#  b'YAKUTAT STATE AP': 'USW00025339',
#  b'YAMBA PILOT STATION': 'ASN00058012',
#  b'YANGON INTL': 'BMM00048097',
#  b'YAP ISLAND WSO AP': 'FMW00040308',
#  b'YARMOUTH A': 'CA008206495',
#  b'YICHANG': 'CHM00057461',
#  b'YINCHUAN': 'CHM00053614',
#  b'YOLA': 'NIM00065167',
#  b'YU ZHONG': 'CHM00052983',
#  b'ZAGREB-GRIC': 'HR000142360',
#  b'ZAHEDAN': 'IR000408560',
#  b'ZAMBOANGA': 'RP000098836',
#  b'ZHARKENT': 'KZ000036859',
#  b'ZHENGZHOU': 'CHM00057083',
#  b'ZHIGANSK': 'RSM00024343',
#  b'ZHIJIANG': 'CHM00057745',
#  b'ZHOB': 'PK000041620',
#  b'ZHONGSHAN': 'AYM00089573',
#  b'ZYRJANKA': 'RSM00025400'}

# %%
def find_station_id(station_mapping, station_name):
    return station_mapping.get(station_name.encode(), None)

# %%
station_name = 'BANGALORE'

# %%
station_id = find_station_id(station_mapping, station_name) # gets the ID for the selected station

file_rel_path = 'gsn/{0}.dly'.format(station_id)
output_name = 'station_daily.txt'
download_url = urllib.parse.urljoin(ftp_url, file_rel_path) # url of the daily summary 

station_file_location = download_url.format(station_id)
urllib.request.urlretrieve(station_file_location, 'station_daily.txt')
# Out:
# ('station_daily.txt', <email.message.Message at 0x195efb736d8>)

# %%
with open('readme.txt','r') as readme_file:
    for line in readme_file.readlines()[98:121]:
        print(line.rstrip())
# Out:
# ------------------------------
# Variable   Columns   Type
# ------------------------------
# ID            1-11   Character
# YEAR         12-15   Integer
# MONTH        16-17   Integer
# ELEMENT      18-21   Character
# VALUE1       22-26   Integer
# MFLAG1       27-27   Character
# QFLAG1       28-28   Character
# SFLAG1       29-29   Character
# VALUE2       30-34   Integer
# MFLAG2       35-35   Character
# QFLAG2       36-36   Character
# SFLAG2       37-37   Character
#   .           .          .
#   .           .          .
#   .           .          .
# VALUE31    262-266   Integer
# MFLAG31    267-267   Character
# QFLAG31    268-268   Character
# SFLAG31    269-269   Character
# ------------------------------

# %%
file_delimiter = [11, 4, 2, 4] + [5, 1, 1, 1] * 31 
selected_columns = [1, 2, 3] + [4*i for i in range(1, 32)]

# column_types contains the column names and their data types
column_types = np.dtype([('YEAR', '>i4'),
                         ('MONTH', '>i4'),
                         ('PROCESS_TYPE', 'U4')] +
                        [('DAY_{0}'.format(i), '>i4') for i in range(1, 32)])

station_raw_data = parse_fixed_file(file_name='station_daily.txt',
                                    file_delimiter=file_delimiter,
                                    selected_columns=selected_columns,
                                    column_types=column_types)

# %%
print(station_raw_data[-5:])
# Out:
# [(2018, 5, 'TAVG',   269, 265,   259, 261,   270, 279, 278,   259, 272,   257,   244,   257,   249,   238,   248,   262,   267,   242, 259,   252,   241,   263,   237,   263,   235,   250,   260,   267,   256,   246,   256)
#  (2018, 6, 'TMAX',   303, 310, -9999, 304, -9999, 297, 301,   290, 258, -9999, -9999, -9999,   283,   279, -9999,   310,   300,   289, 289, -9999, -9999, -9999, -9999, -9999, -9999, -9999, -9999, -9999, -9999, -9999, -9999)
#  (2018, 6, 'TMIN', -9999, 209,   208, 210,   212, 219, 217, -9999, 207,   205,   210,   210,   208,   210,   205,   201,   209,   203, 201, -9999, -9999, -9999, -9999, -9999, -9999, -9999, -9999, -9999, -9999, -9999, -9999)
#  (2018, 6, 'PRCP',     0,  15,    18,  61,     0,   0,   0,     0,  38,    13,    20,     0, -9999, -9999, -9999, -9999, -9999, -9999,   3, -9999, -9999, -9999, -9999, -9999, -9999, -9999, -9999, -9999, -9999, -9999, -9999)
#  (2018, 6, 'TAVG',   244, 238,   237, 238,   248, 256, 239,   233, 220,   226,   237,   242,   241,   232,   238,   241,   236,   235, 238, -9999, -9999, -9999, -9999, -9999, -9999, -9999, -9999, -9999, -9999, -9999, -9999)]

# %%
print(station_raw_data['PROCESS_TYPE'][-10:])
# Out:
# ['PRCP' 'TAVG' 'TMAX' 'TMIN' 'PRCP' 'TAVG' 'TMAX' 'TMIN' 'PRCP' 'TAVG']

# %%
min_year = station_raw_data[0]['YEAR']
max_year = station_raw_data[-1]['YEAR']

print(min_year, max_year)
# Out:
# 1901 2018

# %%
def refactor_monthly_data(monthly_data):
    year = monthly_data['YEAR']
    month = monthly_data['MONTH']
    start = np.datetime64('{0}-{1:02}'.format(year, month))
    month_range = np.arange(start,
                            start + np.timedelta64(1, 'M'),
                            np.timedelta64(1, 'D'))
    current_month_data = [(date, monthly_data['DAY_' + str(day_nr+1)] / 10) for
                          day_nr, date
                          in enumerate(month_range)]
    return np.array(current_month_data,
                    dtype=[('DATE', 'M8[D]'), ('TEMPERATURE', 'd')])

# %%
def take_processing(station_data,
                    processing_type):
    daily_data = np.concatenate([refactor_monthly_data(raw_month)
                                 for raw_month
                                 in station_data
                                 if raw_month[2] == processing_type])
    daily_data['TEMPERATURE'][daily_data['TEMPERATURE'] == -999.9] = np.nan
    return daily_data

# %%
minimums = take_processing(station_raw_data, 'TMIN')
maximums = take_processing(station_raw_data, 'TMAX')
averages = take_processing(station_raw_data, 'TAVG')

# %%
plt.plot(minimums['DATE'], minimums['TEMPERATURE'],color = 'r')
plt.plot(maximums['DATE'], maximums['TEMPERATURE'],color = 'b')
plt.plot(averages['DATE'], averages['TEMPERATURE'],color = 'g')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
nan_val = np.isnan(averages['TEMPERATURE'])
len(averages['TEMPERATURE'][nan_val])
# Out:
# 634

# %%
number_averages = averages[~nan_val]
len(number_averages)
# Out:
# 15983

# %%
plt.plot(number_averages['DATE'], number_averages['TEMPERATURE'])

# %%
fig, ax = plt.subplots()
fig.set_figheight(5)
fig.set_figwidth(10)

ax.set_xlim([np.datetime64('1987-01-01'), np.datetime64('1991-01-01')])

plt.plot(number_averages['DATE'], number_averages['TEMPERATURE'])

plt.legend(['Raw'])

# %%
def floating_avg(dataset, column_name, window=5):
    return np.correlate(dataset[column_name], np.ones((window,))/window, mode='same')

# %%
fig, ax = plt.subplots()
fig.set_figheight(5)
fig.set_figwidth(10)

ax.set_xlim([np.datetime64('1987-01-01'), np.datetime64('1989-01-01')])

plt.plot(number_averages['DATE'], number_averages['TEMPERATURE'])
plt.plot(number_averages['DATE'], floating_avg(number_averages, 'TEMPERATURE', 60))
plt.plot(number_averages['DATE'], floating_avg(number_averages, 'TEMPERATURE', 200))

plt.legend(['Raw', '100-samples', '200-samples'])

# %% [markdown]
# ## Calculating monthly averages

# %%
def get_monthly_data(dataset, year):
    act_monthly_avg = np.full((12, ), np.nan)
    for month_nr in range(1, 12+1):
        start_date = np.datetime64('{0}-{1:02}'.format(year, month_nr))
        end_date = start_date + np.timedelta64(1,'M')
        selected_range = number_averages[(number_averages['DATE'] >= start_date) &
                                         (number_averages['DATE'] <= end_date)]['TEMPERATURE']
        if not np.isnan(selected_range).all():
            act_monthly_avg[month_nr - 1] = np.mean(selected_range)
    return act_monthly_avg

# %%
def process_years(dataset, start_year, end_year):
    all_year_summary = None
    for act_year in np.arange(start_year, end_year + 1):
        act_monthly_avg = get_monthly_data(dataset, act_year)
        act_monthly_avg = np.insert(act_monthly_avg, 0 , act_year)
        if all_year_summary is None:
            all_year_summary = act_monthly_avg
            continue
        
        all_year_summary = np.vstack((all_year_summary, act_monthly_avg))
    return all_year_summary

# %%
result_array = process_years(number_averages, min_year, max_year)
result_array.shape
# Out:
# (118, 13)

# %%
result_array[0]
# Out:
# array([1901.,   nan,   nan,   nan,   nan,   nan,   nan,   nan,   nan,
#          nan,   nan,   nan,   nan])

# %% [markdown]
# Ok, let's do something more interesting. Compare 2 consecutive months in one chart (january and february for example)

# %%
fig, ax = plt.subplots()
def_width = 0.4
left_range = np.arange(result_array.shape[0])
january_data = result_array[:, 1]
february_data = result_array[:, 2]

ax.bar(left=left_range, height=january_data, width=def_width)
ax.bar(left=left_range + def_width, height=february_data, width=def_width)
# Out:
# C:\ProgramData\Anaconda3\envs\py36\lib\site-packages\matplotlib\__init__.py:1717: MatplotlibDeprecationWarning: The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#   return func(ax, *args, **kwargs)
# <Container object of 118 artists>

# %%
structured_result = np.core.records.fromarrays(result_array.transpose(),
                                               dtype=[('year', '<i4')] +
                                                     [('month_{0}'.format(i+1), '<f8') for i in range(12)])

# %%
structured_result[-1:].dtype
# Out:
# dtype((numpy.record, [('year', '<i4'), ('month_1', '<f8'), ('month_2', '<f8'), ('month_3', '<f8'), ('month_4', '<f8'), ('month_5', '<f8'), ('month_6', '<f8'), ('month_7', '<f8'), ('month_8', '<f8'), ('month_9', '<f8'), ('month_10', '<f8'), ('month_11', '<f8'), ('month_12', '<f8')]))

# %%
def get_month_name(month_number):
    return dt.datetime(1900, month_number, 1).strftime('%B')

# %%
for i in range(12):
    fig, ax = plt.subplots()
    ax.plot(structured_result['year'], structured_result['month_{0}'.format(i + 1)], '.--')
    month_name = get_month_name(i + 1)
    ax.set_title(month_name)
    fig.set_figwidth(15)

# %%
def compare_months_scatter(temperature_dataset,
                           months_seq,
                           height=5,
                           width=10):
    fig, ax = plt.subplots(1)
    curve_names = []
    for i in months_seq:
        month_name = get_month_name(i)
        curve_names.append(month_name)
        ax.plot(temperature_dataset['year'],
                temperature_dataset['month_{0}'.format(i)],
                '.--')
        ax.set_title('Monthly comparison')
    fig.set_figheight(height)
    fig.set_figwidth(width)
    legend = ax.legend(curve_names)
    legend.set_frame_on(True)
    frame = legend.get_frame()
    frame.set_edgecolor('r')

# %%
compare_months_scatter(structured_result, (1, 3), 7, 15)
